# %%
from scripts import gee_satellite_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e3e1bcd61f9b> in <module>
# ----> 1 from scripts import gee_satellite_data
#
# ImportError: cannot import name 'gee_satellite_data' from 'scripts' (unknown location)

# %% [markdown]
# The following example aims at searching Sentinel 2-data using a single point.
# For this purpose the users should indicate the point's longitude and latitude in WGS 84 coordinates system.
# Additionally, a initial and ending query dates must be provided.

# %%
## region of interest
longitude = -74.9943
latitude = 3.91708
areaofinfluence = 500 ## this value is the circle radius, that will wrap the area of interest, in meters  

sentinel2 = gee_satellite_data.get_gee_data("2019-07-01",  ## start date
                                            "2019-09-28", ## end query date
                                            point_coordinates= [longitude,latitude], ## region of interest
                                            mission= "sentinel2_sr", ## mission
                                            cloud_percentage= 80, ## clouds percentage allowed per image 
                                            buffer= areaofinfluence                                           
                                           )

sentinel2.summary
# Out:
#         dates  cover_percentage
# 0  2019-07-03         99.533485
# 1  2019-07-13         59.863416
# 2  2019-07-23          0.000000
# 3  2019-08-02         99.533485
# 4  2019-08-07         36.930561
# 5  2019-08-12         99.533485
# 6  2019-08-17         89.191496
# 7  2019-08-22         99.533485
# 8  2019-08-27         99.533485
# 9  2019-09-11         99.533485
# 10 2019-09-16         99.533485
# 11 2019-09-21         99.533485

# %%
### True-color image visualization
## defining visualization parameters
truecolorParams = {'gamma': 1.3, 
                   'min': 57,
                   'max': 2000,
                   'bands': ['B4','B3','B2']
                   }
## image selection
image_index = 9
imagetoplot = sentinel2.image_collection.toList(sentinel2.image_collection.size()).get(image_index)
## Visualization
gee_satellite_data.plot_eeimage(imagetoplot, truecolorParams, sentinel2.geometry, zoom = 14)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
### adding the ndvi layer
sentinel2.add_vi_layer("ndvi")

### NDVI image visualization

## defining visualization parameters
ndviParams = {     'min': 0,
                   'max': 1,
                   'palette': ['#FF0000', '#00FF00'],
                   'bands': ['ndvi']
                   }
## image selection
image_index = 9
imagetoplot = sentinel2.image_collection.toList(sentinel2.image_collection.size()).get(image_index)

## Visualization
gee_satellite_data.plot_eeimage(imagetoplot, ndviParams, sentinel2.geometry, zoom = 14)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import ee
ee.Initialize()
def reduce_tosingle_columns(image, region):
    mean = image.reduceRegions(region,'mean',10);
  
    return mean.map(lambda f: 
                    f.set('date', ee.Date(image.get('system:time_start')).
                          format('YYYY-MM-dd'))
  )


meanDictionary = sentinel2.image_collection.map(lambda img: 
                                                reduce_tosingle_columns(img, 
                                                                        sentinel2._ee_sp)).flatten()
print(meanDictionary.getInfo())
print('sdsa')
fields = ["date", "admin2RefN",'avg_rad'];

#result = ee.FeatureCollection([ee.Feature(ee.null, ee.Dictionary.fromLists(fields, fields))])
#    .merge(meanDictionary)

#var meanDictionary=result.filter(ee.Filter.neq('avg_rad', null))
# Out:
# {'type': 'FeatureCollection', 'columns': {}, 'features': [{'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[-74.9943, 3.9215794329757463], [-74.99555970100272, 3.9214003545991973], [-74.99671912829263, 3.9208773743279473], [-74.997685990417, 3.9200521219818567], [-74.99838332490759, 3.9189902884241636], [-74.99875562456886, 3.9177763963262886], [-74.9987732556537, 3.9165070719383923], [-74.9984348163018, 3.9152833535029457], [-74.99776724763653, 3.9142026486042294], [-74.99682368883029, 3.913350980650592], [-74.99567924700624, 3.9127961416300603], [-74.99442501876081, 3.912582296111679], [-74.9931608391781,